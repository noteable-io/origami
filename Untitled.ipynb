# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys, logging
logging.basicConfig(format='%(asctime)s | %(levelname)s : %(message)s',
                      level=logging.DEBUG, stream=sys.stdout)

# %%
from origami.client import NoteableClient

token = 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6IkxsRHRvdEFkd3VJR2NWMVZicE12OSJ9.....K0Cvd2JQEA_QNA6273hgWZqTmrWVaNQ2uhY6HTE1QjGUf90_xcb91q-_DiAmRzznl2p06GbJqQgofD_lXq3iIxJfcd-rERQm8HnxvQerfl6qEopFCkwYoUNsmstQ-0BwTKmrraGDwy-dwaAY-7HLYqJQvCmGHbQVlPZqPmOUAD4y_St7LUxOCvA0ZU7rE5eE1kdi29_bNF6ZyS9VVe2BESvNOEDY8ZoJRqbo0TrBBmRXleUGOXoz87P3BhZ-q4Y8hAbge9Lo_v4TLoErev1OcksHKNRb-XvikpxkumQ--HLBE_1yyBVnrU4SEEoIkHjNVAwz5_l-2Ulezddu9K6OAQ'

async with NoteableClient(token, 'app.noteable-integration.us') as client:
     print(await client.subscribe_file('fa484ab6-a8db-425b-8db6-1f65efa985a8'))
# Out:
# 2022-05-12 14:25:24,751 | DEBUG : client - state = CONNECTING
# 2022-05-12 14:25:24,831 | DEBUG : client - event = connection_made(<asyncio.sslproto._SSLProtocolTransport object at 0x7f5b59c83460>)
# 2022-05-12 14:25:24,834 | DEBUG : client > GET /gate/api/v1/rtu HTTP/1.1
# ...
